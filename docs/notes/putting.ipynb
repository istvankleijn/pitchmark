# %%
import pathlib

import altair as alt
import geopandas as gpd
import laspy
import logging
import numpy as np
import open3d as o3d
import pyproj
import shapely 

import pitchmark
import pitchmark.osm
import pitchmark.lidar

# %%
logging.basicConfig(level=logging.INFO)

# %%
logging.getLogger()
# Out:
# <RootLogger root (INFO)>

# %%
logging.warning("abc")
logging.info("def")
# Out:
# WARNING:root:abc
# INFO:root:def

# %%
map_path = pathlib.Path().cwd() / "OpenStreetMap" / "augusta_national" / "map.osm"
handler = pitchmark.osm.GolfHandler()
handler.apply_file(map_path)
fc = handler.feature_collection
augusta_national = pitchmark.Course.from_featurecollection(fc)

# %%
geoseries = augusta_national.gdf.geometry
geoseries
# Out:
# 168    POLYGON ((-364.377 210.856, -364.295 207.363, ...
# 222    POLYGON ((-399.804 -688.022, -398.869 -692.801...
# 158    POLYGON ((-167.382 -395.922, -159.639 -418.350...
# 138    POLYGON ((-106.194 -302.804, -105.249 -314.509...
# 135    POLYGON ((-181.484 -183.993, -181.413 -186.310...
#                              ...
# 112    POLYGON ((-183.500 -421.879, -177.088 -422.219...
# 34     POLYGON ((-94.679 -80.650, -94.435 -81.656, -9...
# 161    POLYGON ((-245.263 -280.750, -230.011 -333.381...
# 32     POLYGON ((-179.462 -186.079, -179.370 -186.953...
# 31     POLYGON ((-173.079 -166.866, -173.039 -167.715...
# Name: geometry, Length: 204, dtype: geometry

# %%
azalea = augusta_national.holes[12]
azalea
# Out:
# Hole(hole_number=13, name='Azalea', path=<LINESTRING (-82.024 33.494, -82.024 33.496, -82.025 33.497, -82.026 33.497)>)

# %%
redbud = augusta_national.holes[15]
redbud
# Out:
# Hole(hole_number=16, name='Redbud', path=<LINESTRING (-82.026 33.498, -82.026 33.5)>)

# %%
folder = pathlib.Path().cwd() / "USGS_LIDAR"
files = [
    "USGS_LPC_GA_Statewide_2018_B18_DRRA_e1284n1253.laz",
    "USGS_LPC_GA_Statewide_2018_B18_DRRA_e1284n1254.laz",
    "USGS_LPC_GA_Statewide_2018_B18_DRRA_e1285n1253.laz",
    "USGS_LPC_GA_Statewide_2018_B18_DRRA_e1285n1254.laz",
]
paths = [folder / file for file in files]
paths
# Out:
# [WindowsPath('c:/Users/Istvan/OneDrive/dev/pitchmark/data-raw/USGS_LIDAR/USGS_LPC_GA_Statewide_2018_B18_DRRA_e1284n1253.laz'),
#  WindowsPath('c:/Users/Istvan/OneDrive/dev/pitchmark/data-raw/USGS_LIDAR/USGS_LPC_GA_Statewide_2018_B18_DRRA_e1284n1254.laz'),
#  WindowsPath('c:/Users/Istvan/OneDrive/dev/pitchmark/data-raw/USGS_LIDAR/USGS_LPC_GA_Statewide_2018_B18_DRRA_e1285n1253.laz'),
#  WindowsPath('c:/Users/Istvan/OneDrive/dev/pitchmark/data-raw/USGS_LIDAR/USGS_LPC_GA_Statewide_2018_B18_DRRA_e1285n1254.laz')]

# %%
# las_classes = [
#     pitchmark.lidar.las.LasClassification.unclassified,
#     pitchmark.lidar.las.LasClassification.ground,
# ]
# pitchmark.lidar.las.clip_to_geoseries(
#     paths,
#     geoseries,
#     classification_filter=las_classes,
#     to_file=folder / "augusta_national_unclassified_or_ground.laz",
# )
ground = laspy.read(folder / "augusta_national_ground.laz")

# %%
augusta_national.populate_hole_meshes(folder / "augusta_national_ground.laz", smooth_iters=10)
# Out:
# INFO:root:Populating hole meshes from c:\Users\Istvan\OneDrive\dev\pitchmark\data-raw\USGS_LIDAR\augusta_national_ground.laz:
# INFO:root:Preparing hole 1...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 2...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 3...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 4...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 5...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 6...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 7...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 8...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 9...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 10...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 11...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 12...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 13...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 14...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 15...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 16...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 17...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Preparing hole 18...
# INFO:root:Constructing Delaunay triangles...
# INFO:root:Constructing 3D mesh...
# INFO:root:Aggregating dataframe...
# INFO:root:Done!

# %%
redbud = augusta_national.holes[15]
redbud
# Out:
# Hole(hole_number=16, name='Redbud', path=<LINESTRING (-82.026 33.498, -82.026 33.5)>)

# %%
redbud_flag = augusta_national.transformer_to_local.transform(*redbud.path.coords[-1])
redbud_flag
# Out:
# (-671.6084493783727, -338.06800716476437)

# %%
redbud_green = redbud.gdf[
    redbud.gdf.contains(shapely.Point(redbud_flag))
    & (redbud.gdf["course_area"] == "putting_green")
].unary_union
redbud_green_surround = redbud_green.buffer(5.0)
shapely.prepare(redbud_green_surround)
redbud_green_surround
# Out:
# <POLYGON ((-698.486 -332.108, -698.387 -331.605, -698.236 -331.116, -698.037...>

# %%
surround_features = pitchmark.plotting.chart_course(redbud.gdf.clip(redbud_green_surround))

# %%
selected_mesh = redbud.mesh[redbud.mesh.within(redbud_green)]
selector = alt.selection_single(on="mouseover", nearest=True)
inclines = (
    alt.Chart(selected_mesh)
    .mark_point(
        shape="wedge",
        filled=True,
        color="lightgray",
    )
    .encode(
        longitude="x",
        latitude="y",
        color=alt.condition(
            selector,
            alt.value("red"),
            alt.Color("slope_grade:Q", scale=alt.Scale(domain=[0, 12.0], scheme="greys")),
        ),
        angle="slope_heading",
        size="slope_grade",
        tooltip=["z", "slope_heading", "slope_grade"],
    )
    .add_selection(selector)
    .project(
        type="identity",
        reflectY=True,
    )
    .properties(
        width=800,
        height=800,
    )
)

# %%
surround_features + inclines
# Out:
# alt.LayerChart(...)

# %%
xmin, ymin, xmax, ymax = redbud_green.bounds
xmin, ymin, xmax, ymax
# Out:
# (-693.6702619082821,
#  -358.95588959757555,
#  -655.0035154292822,
#  -322.068723330571)

# %%
cell_size = 1.0
nx = int((xmax - xmin) / cell_size)
np.linspace(xmin, xmax, nx)
# Out:
# array([-693.67026191, -692.62521471, -691.5801675 , -690.5351203 ,
#        -689.4900731 , -688.4450259 , -687.3999787 , -686.35493149,
#        -685.30988429, -684.26483709, -683.21978989, -682.17474268,
#        -681.12969548, -680.08464828, -679.03960108, -677.99455388,
#        -676.94950667, -675.90445947, -674.85941227, -673.81436507,
#        -672.76931787, -671.72427066, -670.67922346, -669.63417626,
#        -668.58912906, -667.54408185, -666.49903465, -665.45398745,
#        -664.40894025, -663.36389305, -662.31884584, -661.27379864,
#        -660.22875144, -659.18370424, -658.13865704, -657.09360983,
#        -656.04856263, -655.00351543])

# %%
xrange, xadd = divmod(xmax - xmin, cell_size)
yrange, yadd = divmod(ymax - ymin, cell_size)

# %%
# Square grid
# xspace = cell_size
# yspace = cell_size
# xs = np.arange(xmin + xadd/2, xmax, xspace)
# ys = np.arange(ymin + yadd/2, ymax, yspace)
# Hex grid is equal to two overlapping rectangular grids
xspace = cell_size
yspace = cell_size * np.sqrt(3)
xs1 = np.arange(xmin + xadd/2, xmax, xspace)
ys1 = np.arange(ymin + yadd/2, ymax, yspace)
grid1 = [shapely.Point(x, y) for x in xs1 for y in ys1]

# %%
xs2 = np.arange(xmin + xadd/2 - xspace/2, xmax, xspace)
ys2 = np.arange(ymin + yadd/2 + yspace/2, ymax, yspace)
grid2 = [shapely.Point(x, y) for x in xs2 for y in ys2]
grid_points = grid1 + grid2

# %%
len(grid_points)
# Out:
# 1677

# %%
gdf = gpd.sjoin(
    gpd.GeoDataFrame(geometry=grid_points, crs=redbud.mesh.crs),
    redbud.mesh,
    how="left",
    predicate="within"
).clip(redbud_green)

# %%
len(gdf)
# Out:
# 919

# %%
gdf["lat"] = gdf.geometry.x
gdf["lon"] = gdf.geometry.y
gdf
# Out:
#                        geometry  index_right           x           y  \
# 511   POINT (-670.337 -349.852)        21400 -670.629205 -349.515518
# 1325  POINT (-671.837 -348.986)        21181 -671.780756 -349.310223
# 1346  POINT (-670.837 -348.986)        21179 -670.964251 -349.465774
# 468   POINT (-672.337 -348.120)        21405 -672.228596 -348.310835
# 512   POINT (-670.337 -348.120)        21595 -670.574010 -347.716494
# ...                         ...          ...         ...         ...
# 504   POINT (-671.337 -323.871)        19325 -671.401978 -323.507488
# 526   POINT (-670.337 -323.871)        19794 -670.245425 -323.866956
# 482   POINT (-672.337 -323.871)        19322 -672.559462 -323.922628
# 1319  POINT (-672.837 -323.005)        18834 -672.436772 -322.837418
# 1340  POINT (-671.837 -323.005)        19326 -671.443557 -322.987579
#
#               z  normal_x  normal_y  normal_z  slope_heading  slope_grade  \
# 511   70.156184  0.054354  0.021687  0.998286      68.248493     5.852041
# 1325  70.185321 -0.014467 -0.005394  0.999881     249.550435     1.543975
# 1346  70.170774  0.037644  0.022883  0.999029      58.705517     4.405307
# 468   70.201025  0.032102  0.003988  0.999477      82.919107     3.234830
# 512   70.131453  0.028550  0.005252  0.999579      79.577122     2.902900
# ...         ...       ...       ...       ...            ...          ...
# 504   71.341761 -0.028635 -0.097235  0.994849     196.409392    10.136326
# 526   71.338507 -0.024170 -0.071878  0.997121     198.585930     7.583299
# 482   71.278957 -0.001892 -0.069644  0.997570     181.556480     6.967002
# 1319  71.369071 -0.022095 -0.067215  0.997494     198.196868     7.075395
# 1340  71.382905 -0.024689 -0.069428  0.997281     199.575996     7.368708
#
#              lat         lon
# 511  -670.336889 -349.852052
# 1325 -671.836889 -348.986027
# 1346 -670.836889 -348.986027
# 468  -672.336889 -348.120002
# 512  -670.336889 -348.120002
# ...          ...         ...
# 504  -671.336889 -323.871290
# 526  -670.336889 -323.871290
# 482  -672.336889 -323.871290
# 1319 -672.836889 -323.005265
# 1340 -671.836889 -323.005265
#
# [919 rows x 12 columns]

# %%
selector = alt.selection_single(on="mouseover", nearest=True)
inclines = (
    alt.Chart(gdf)
    .mark_point(
        shape="wedge",
        filled=True,
        color="lightgray",
    )
    .encode(
        longitude="lat",
        latitude="lon",
        color=alt.condition(
            selector,
            alt.value("red"),
            alt.Color("slope_grade:Q", scale=alt.Scale(domainMin=0.0, scheme="greys")),
        ),
        angle="slope_heading",
        size="slope_grade",
        tooltip=["z", "slope_heading", "slope_grade"],
    )
    .add_selection(selector)
    .project(
        type="identity",
        reflectY=True,
    )
    .properties(
        width=600,
        height=600,
    )
)

# %%
surround_features = pitchmark.plotting.chart_course(
    redbud.gdf.clip(redbud_green_surround)
).project(
    type="identity",
    reflectY=True,
)

# %%
(surround_features + inclines)
# Out:
# alt.LayerChart(...)

# %%
# Need to check that Taubin smoothening does not rotate the mesh so gravity is no longer pointing down!

# %%
np.tan(np.deg2rad(2))
# Out:
# 0.03492076949174773

# %%
redbud_green.area*9
# Out:
# 7143.265361859608

# %%
triangle_mesh = pitchmark.geom.simplified_mesh(redbud.mesh.geometry)

# %%
np.asarray(triangle_mesh.vertices)
# Out:
# array([[-722.22391681, -324.2613008 ,   70.7865312 ],
#        [-723.76345693, -329.83648747,   70.67842088],
#        [-723.07372137, -326.63133448,   70.78920083],
#        ...,
#        [-596.94101047, -494.97546881,   69.30917599],
#        [-596.0140074 , -497.27489922,   69.29493118],
#        [-594.52874485, -498.05657249,   69.3195289 ]])

# %%
ground.header.parse_crs()
# Out:
# <Compound CRS: COMPD_CS["NAD83(2011) / Conus Albers + NAVD88 heig ...>
# Name: NAD83(2011) / Conus Albers + NAVD88 height - Geoid12B (Meters)
# Axis Info [cartesian|vertical]:
# - [east]: X (metre)
# - [north]: Y (metre)
# - [up]: Gravity-related height (metre)
# Area of Use:
# - undefined
# Datum: NAD83 (National Spatial Reference System 2011)
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich
# Sub CRS:
# - NAD83(2011) / Conus Albers
# - NAVD88 height

# %%
augusta_national.gdf.crs
# Out:
# <Projected CRS: +proj=tmerc +lon_0=-82.0198831 +lat_0=33.5023672 + ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (yard)
# - N[north]: Northing (yard)
# - h[up]: Ellipsoidal height (yard)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unknown
# - method: Transverse Mercator
# Datum: Unknown based on WGS84 ellipsoid
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
augusta_national.gdf
# Out:
#         name   course_area ground_cover  \
# 168    woods  general_area        woods
# 222    rough  general_area   long_grass
# 158    woods  general_area        woods
# 138  fairway  general_area  short_grass
# 135  fairway  general_area  short_grass
# ..       ...           ...          ...
# 112      tee   teeing_area  short_grass
# 34   bunkers        bunker         sand
# 161    woods  general_area        woods
# 32   bunkers        bunker         sand
# 31   bunkers        bunker         sand
#
#                                               geometry
# 168  POLYGON ((-364.377 210.856, -364.295 207.363, ...
# 222  POLYGON ((-399.804 -688.022, -398.869 -692.801...
# 158  POLYGON ((-167.382 -395.922, -159.639 -418.350...
# 138  POLYGON ((-106.194 -302.804, -105.249 -314.509...
# 135  POLYGON ((-181.484 -183.993, -181.413 -186.310...
# ..                                                 ...
# 112  POLYGON ((-183.500 -421.879, -177.088 -422.219...
# 34   POLYGON ((-94.679 -80.650, -94.435 -81.656, -9...
# 161  POLYGON ((-245.263 -280.750, -230.011 -333.381...
# 32   POLYGON ((-179.462 -186.079, -179.370 -186.953...
# 31   POLYGON ((-173.079 -166.866, -173.039 -167.715...
#
# [204 rows x 4 columns]

# %%
dir(gpd.io.file)
# Out:
# ['BaseGeometry',
#  'FIONA_GE_19',
#  'GeoDataFrame',
#  'GeoSeries',
#  'Path',
#  'Version',
#  '_EXTENSION_TO_DRIVER',
#  '_VALID_URLS',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_engine',
#  '_check_fiona',
#  '_check_pyogrio',
#  '_detect_driver',
#  '_expand_user',
#  '_geometry_types',
#  '_import_fiona',
#  '_import_pyogrio',
#  '_is_url',
#  '_is_zip',
#  '_read_file',
#  '_read_file_fiona',
#  '_read_file_pyogrio',
#  '_to_file',
#  '_to_file_fiona',
#  '_to_file_pyogrio',
#  '_urlopen',
#  'fiona',
#  'fiona_env',
#  'fiona_import_error',
#  'infer_schema',
#  'is_integer_dtype',
#  'mapping',
#  'np',
#  'os',
#  'parse_url',
#  'pd',
#  'pyogrio',
#  'pyogrio_import_error',
#  'pyproj',
#  'read_file',
#  'to_file',
#  'uses_netloc',
#  'uses_params',
#  'uses_relative',
#  'warnings']

# %%
# ?gpd.io.file.to_file
# Out:
# Signature: gpd.io.file.to_file(*args, **kwargs)
# Docstring: <no docstring>
# File:      c:\users\istvan\miniconda3\envs\pitchmark_py310\lib\site-packages\geopandas\io\file.py
# Type:      function

# %%
redbud.gdf.to_csv(folder / "redbud_gdf.csv")

# %%
pd.from_csv(folder / "redbud_gdf.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 pd.from_csv(folder / "redbud_gdf.csv")
#
# File c:\Users\Istvan\miniconda3\envs\pitchmark_py310\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'from_csv'

# %%
redbud_df_from_csv = pd.read_csv(folder / "redbud_gdf.csv", index_col=0)
geometry = gpd.GeoSeries.from_wkt(redbud_df_from_csv["geometry"])
gdf = gpd.GeoDataFrame(data=redbud_df_from_csv, geometry=geometry)

# %%
redbud.mesh.to_csv(folder / "redbud_mesh.csv")

# %%
# Out:
#              name    course_area ground_cover  \
# 197         woods   general_area        woods
# 100           tee    teeing_area  short_grass
# 217         rough   general_area   long_grass
# 4    water_hazard   penalty_area        water
# 145       fairway   general_area  short_grass
# 172         woods   general_area        woods
# 28        bunkers         bunker         sand
# 29        bunkers         bunker         sand
# 70          green  putting_green        green
# 164         woods   general_area        woods
# 218         rough   general_area   long_grass
# 30        bunkers         bunker         sand
# 89            tee    teeing_area  short_grass
# 142       fairway   general_area  short_grass
# 143       fairway   general_area  short_grass
# 176         woods   general_area        woods
# 122       fairway   general_area  short_grass
#
#                                               geometry
# 197  POLYGON ((-591.987 -508.373, -589.120 -506.813...
# 100  POLYGON ((-612.319 -460.423, -592.200 -499.142...
# 217  POLYGON ((-591.987 -508.373, -595.769 -509.971...
# 4    POLYGON ((-695.338 -347.746, -694.647 -347.528...
# 145  POLYGON ((-697.073 -311.733, -692.917 -315.942...
# 172  POLYGON ((-596.440 -362.890, -600.160 -365.364...
# 28   POLYGON ((-654.425 -351.048, -654.059 -350.162...
# 29   POLYGON ((-694.596 -342.749, -694.372 -342.021...
# 70   POLYGON ((-693.538 -332.827, -693.203 -332.135...
# 164  POLYGON ((-655.582 -319.462, -653.935 -319.110...
# 218  POLYGON ((-593.880 -370.956, -597.599 -373.649...
# 30   POLYGON ((-676.718 -314.160, -675.631 -312.547...
# 89   POLYGON ((-672.084 -297.701, -639.027 -309.687...
# 142  POLYGON ((-702.417 -295.515, -701.148 -302.696...
# 143  POLYGON ((-702.417 -295.515, -701.148 -302.696...
# 176  POLYGON ((-673.191 -289.853, -674.664 -290.799...
# 122  POLYGON ((-594.038 -468.927, -596.741 -468.854...

# %%
import dataclasses
import functools
import operator
import pathlib
import warnings

import altair as alt
import geopandas as gpd
import pandas as pd
import pyproj
import shapely
import shapely.plotting

import pitchmark
import pitchmark.osm

# %%
METERS_PER_YARD = 0.9144
WGS84_EQUATORIAL_RADIUS = 6_378_137.0  # meters
WGS84_INVERSE_FLATTENING = 298.257_223_563

# %%
map_path = pathlib.Path(".") / "augusta_national" / "map.osm"
handler = pitchmark.osm.GolfHandler()
handler.apply_file(map_path)
fc = handler.feature_collection
augusta_national = pitchmark.Course.from_featurecollection(fc)

# %%
len(augusta_national.gdf)
# Out:
# 204

# %%
ch = augusta_national.chart()
ch
# Out:
# alt.Chart(...)

# %%
isinstance(ch, alt.Chart)
# Out:
# True

# %%
augusta_national.gdf
# Out:
#         name   course_area ground_cover  \
# 168    woods  general_area        woods
# 222    rough  general_area   long_grass
# 158    woods  general_area        woods
# 138  fairway  general_area  short_grass
# 135  fairway  general_area  short_grass
# ..       ...           ...          ...
# 112      tee   teeing_area  short_grass
# 34   bunkers        bunker         sand
# 161    woods  general_area        woods
# 32   bunkers        bunker         sand
# 31   bunkers        bunker         sand
#
#                                               geometry
# 168  POLYGON ((-364.377 210.856, -364.295 207.363, ...
# 222  POLYGON ((-399.804 -688.022, -398.869 -692.801...
# 158  POLYGON ((-167.382 -395.922, -159.639 -418.350...
# 138  POLYGON ((-106.194 -302.804, -105.249 -314.509...
# 135  POLYGON ((-181.484 -183.993, -181.413 -186.310...
# ..                                                 ...
# 112  POLYGON ((-183.500 -421.879, -177.088 -422.219...
# ...

# %%
augusta_national.gdf.crs
# Out:
# <Derived Projected CRS: +proj=tmerc +lon_0=-82.0198831 +lat_0=33.5023672 + ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (yard)
# - N[north]: Northing (yard)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unknown
# - method: Transverse Mercator
# Datum: Unknown based on WGS84 ellipsoid
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
augusta_national.holes
# Out:
# [Hole(hole_number=1, name='Tea Olive', path=<LINESTRING (-82.02 33.502, -82.022 33.504, -82.024 33.504)>),
#  Hole(hole_number=2, name='Pink Dogwood', path=<LINESTRING (-82.024 33.505, -82.025 33.502, -82.024 33.501, -82.024 33.5)>),
#  Hole(hole_number=3, name='Flowering Peach', path=<LINESTRING (-82.023 33.5, -82.025 33.501, -82.026 33.502)>),
#  Hole(hole_number=4, name='Flowering Crab Apple', path=<LINESTRING (-82.026 33.502, -82.028 33.502)>),
#  Hole(hole_number=5, name='Magnolia', path=<LINESTRING (-82.029 33.502, -82.028 33.5, -82.028 33.499, -82.027 33.498)>),
#  Hole(hole_number=6, name='Juniper', path=<LINESTRING (-82.027 33.499, -82.027 33.5)>),
#  Hole(hole_number=7, name='Pampas', path=<LINESTRING (-82.027 33.501, -82.025 33.5, -82.023 33.499)>),
#  Hole(hole_number=8, name='Yellow Jasmine', path=<LINESTRING (-82.022 33.499, -82.023 33.502, -82.023 33.503, -82.024 33.504)>),
# ...

# %%
hole_charts = [hole.chart() for hole in augusta_national.holes]

# %%
for chart in hole_charts:
    chart.display()
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %%
azalea_chart_dict = hole_charts[12].to_dict()

# %%
azalea_chart_dict["mark"]
# Out:
# 'geoshape'

# %%
azalea_chart_dict
# Out:
# {'config': {'view': {'continuousWidth': 400, 'continuousHeight': 300},
#   'legend': {'disable': True}},
#  'data': {'name': 'data-23fe2ac199a5ea6854b49c9051ac5f1b'},
#  'mark': 'geoshape',
#  'encoding': {'color': {'field': 'ground_cover',
#    'scale': {'domain': ['water',
#      'sand',
#      'green',
#      'short_grass',
#      'woods',
#      'long_grass'],
#     'range': ['RoyalBlue',
#      'Khaki',
#      'Aquamarine',
#      'LawnGreen',
#      'ForestGreen',
#      'LimeGreen']},
#    'type': 'nominal'},
#   'tooltip': [{'field': 'name', 'type': 'nominal'},
#    {'field': 'ground_cover', 'type': 'nominal'},
#    {'field': 'course_area', 'type': 'nominal'}]},
#  'projection': {'reflectY': True, 'type': 'identity'},
#  'title': '13 - Azalea',
#  '$schema': 'https://vega.github.io/schema/vega-lite/v4.17.0.json',
#  'datasets': {'data-23fe2ac199a5ea6854b49c9051ac5f1b': [{'name': 'rough',
#     'course_area': 'general_area',
#     'ground_cover': 'long_grass',
# ...

# %%
augusta_national.gdf
# Out:
#         name   course_area ground_cover  \
# 168    woods  general_area        woods
# 222    rough  general_area   long_grass
# 158    woods  general_area        woods
# 138  fairway  general_area  short_grass
# 135  fairway  general_area  short_grass
# ..       ...           ...          ...
# 112      tee   teeing_area  short_grass
# 34   bunkers        bunker         sand
# 161    woods  general_area        woods
# 32   bunkers        bunker         sand
# 31   bunkers        bunker         sand
#
#                                               geometry
# 168  POLYGON ((-364.377 210.856, -364.295 207.363, ...
# 222  POLYGON ((-399.804 -688.022, -398.869 -692.801...
# 158  POLYGON ((-167.382 -395.922, -159.639 -418.350...
# 138  POLYGON ((-106.194 -302.804, -105.249 -314.509...
# 135  POLYGON ((-181.484 -183.993, -181.413 -186.310...
# ..                                                 ...
# 112  POLYGON ((-183.500 -421.879, -177.088 -422.219...
# ...

# %%
import pathlib

import geopandas as gpd
import pandas as pd
import shapely

from pitchmark.physics.rolling import *
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
folder = pathlib.Path().cwd() / "USGS_LIDAR"

# %%
mesh_from_csv = pd.read_csv(folder / "redbud_mesh.csv", index_col=0)
mesh_geom = gpd.GeoSeries.from_wkt(mesh_from_csv["geometry"])
mesh_gdf = gpd.GeoDataFrame(data=mesh_from_csv, geometry=mesh_geom)

# %%
df_from_csv = pd.read_csv(folder / "redbud_gdf.csv", index_col=0)
hole_geom = gpd.GeoSeries.from_wkt(df_from_csv["geometry"])
hole_gdf = gpd.GeoDataFrame(data=df_from_csv, geometry=hole_geom)

# %%
mesh_gdf
# Out:
#                                                 geometry           x  \
# 0      POLYGON Z ((-722.370 -324.132 70.786, -723.880... -723.129016
# 1      POLYGON Z ((-722.370 -324.132 70.786, -723.137... -722.590392
# 2      POLYGON Z ((-722.370 -324.132 70.786, -722.264... -721.602992
# 3      POLYGON Z ((-722.370 -324.132 70.786, -720.174... -721.041210
# 4      POLYGON Z ((-722.370 -324.132 70.786, -720.579... -721.589934
# ...                                                  ...         ...
# 22263  POLYGON Z ((-595.573 -498.149 69.296, -595.955... -596.007229
# 22264  POLYGON Z ((-596.494 -497.967 69.279, -595.955... -596.571854
# 22265  POLYGON Z ((-597.267 -496.658 69.288, -596.974... -597.360815
# 22266  POLYGON Z ((-596.513 -487.339 69.293, -594.856... -595.458970
# 22267  POLYGON Z ((-607.687 -495.378 69.106, -609.304... -608.675526
#
#                 y          z  normal_x  normal_y  normal_z  slope_heading  \
# 0     -326.857478  70.750255 -0.447005  0.136095 -0.884118     286.933337
# 1     -325.580938  70.787177  0.012621 -0.001231  0.999920      95.571186
# 2     -324.812896  70.755471  0.040295  0.000333  0.999188      89.527164
# 3     -323.835504  70.746486  0.037559 -0.034685  0.998692     132.721782
# 4     -323.186278  70.783272  0.029778 -0.021502  0.999325     125.832017
# ...           ...        ...       ...       ...       ...            ...
# 22263 -497.790756  69.289246 -0.019387 -0.005579  0.999796     253.945912
# 22264 -497.293754  69.286532 -0.010101 -0.012607  0.999870     218.701699
# 22265 -495.569077  69.303853  0.000983 -0.014904  0.999888     176.224626
# 22266 -487.231491  69.273740  0.016208  0.016165  0.999738      45.075177
# 22267 -495.538174  69.049405 -0.056411 -0.007427  0.998380     262.499236
#
#        slope_grade
# 0        46.726346
# 1         1.268077
# 2         4.029670
# 3         5.112406
# 4         3.673009
# ...            ...
# 22263     2.017335
# 22264     1.615465
# 22265     1.493644
# 22266     2.289144
# 22267     5.689822
#
# [22268 rows x 9 columns]

# %%
green_mesh_gdf = mesh_gdf.overlay(
    hole_gdf[hole_gdf.course_area == "putting_green"], how="intersection"
)

# %%
x0, y0 = -690.0, -337.0

# %%
redbud_green = Green(12.0, hole_location=(x0, y0), gdf=green_mesh_gdf,)

# %%
redbud_green.normal(x0 + 5, y0 + 5)
# Out:
# array([[-0.00697227, -0.0738989 ,  0.99724136]])

# %%
green_mesh_gdf.columns
# Out:
# Index(['x', 'y', 'z', 'normal_x', 'normal_y', 'normal_z', 'slope_heading',
#        'slope_grade', 'name', 'course_area', 'ground_cover', 'geometry'],
#       dtype='object')
